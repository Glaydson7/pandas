# %%
import pandas as pd
import numpy as np

# %%
dias = pd.date_range(start='20190101', periods=12)

# %%
dias
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
Pessoa = ['George', 'Victor', 'Lucas']

# %%
 np.random.choice(Pessoa)
# Out:
# 'Lucas'

# %%
Nome = []
Gasto = []
for i in range(12):
    Nome.append(np.random.choice(Pessoa))
    Gasto.append(np.round(np.random.rand()*100, 2))

Nome
# Out:
# ['Lucas',
#  'Lucas',
#  'Victor',
#  'Victor',
#  'George',
#  'Victor',
#  'Victor',
#  'George',
#  'George',
#  'Lucas',
#  'Lucas',
#  'Victor']

# %%
Gasto
# Out:
# [37.79,
#  78.33,
#  64.41,
#  84.72,
#  68.76,
#  52.98,
#  58.79,
#  1.28,
#  73.18,
#  35.35,
#  56.78,
#  66.85]

# %%
df = pd.DataFrame({'Dia': dias, 'Nome': Nome, 'Gasto': Gasto})

# %%
df
# Out:
#           Dia    Nome  Gasto
# 0  2019-01-01   Lucas  37.79
# 1  2019-01-02   Lucas  78.33
# 2  2019-01-03  Victor  64.41
# 3  2019-01-04  Victor  84.72
# 4  2019-01-05  George  68.76
# 5  2019-01-06  Victor  52.98
# 6  2019-01-07  Victor  58.79
# 7  2019-01-08  George   1.28
# 8  2019-01-09  George  73.18
# 9  2019-01-10   Lucas  35.35
# 10 2019-01-11   Lucas  56.78
# 11 2019-01-12  Victor  66.85

# %%
df.pivot(index='Dia', columns='Nome', values='Gasto')
# Out:
# Nome        George  Lucas  Victor
# Dia
# 2019-01-01     NaN  37.79     NaN
# 2019-01-02     NaN  78.33     NaN
# 2019-01-03     NaN    NaN   64.41
# 2019-01-04     NaN    NaN   84.72
# 2019-01-05   68.76    NaN     NaN
# 2019-01-06     NaN    NaN   52.98
# 2019-01-07     NaN    NaN   58.79
# 2019-01-08    1.28    NaN     NaN
# 2019-01-09   73.18    NaN     NaN
# 2019-01-10     NaN  35.35     NaN
# 2019-01-11     NaN  56.78     NaN
# 2019-01-12     NaN    NaN   66.85
