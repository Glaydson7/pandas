# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20180101', periods=600, freq="D")

df = pd.DataFrame(np.random.randn(600, 5), index=datas, columns=list("ABCDE"))

# %%
df.head(2)
# Out:
#                    A         B         C         D         E
# 2018-01-01 -2.684927 -1.139564 -1.192824 -0.062274  0.360303
# 2018-01-02  0.325065  0.273304 -0.542972  0.362559 -1.695097

# %%
df['D'].head(5)
# Out:
# 2018-01-01   -0.062274
# 2018-01-02    0.362559
# 2018-01-03    0.320732
# 2018-01-04    1.752690
# 2018-01-05   -1.293073
# Freq: D, Name: D, dtype: float64

# %%
df.head(10)
# Out:
#                    A         B         C         D         E
# 2018-01-01 -2.684927 -1.139564 -1.192824 -0.062274  0.360303
# 2018-01-02  0.325065  0.273304 -0.542972  0.362559 -1.695097
# 2018-01-03  0.566284  0.955994 -1.219319  0.320732 -1.078282
# 2018-01-04 -1.078971  0.500797 -0.804943  1.752690  0.048946
# 2018-01-05  0.001632 -0.239746  0.824127 -1.293073 -1.384304
# 2018-01-06 -1.222225 -0.603802 -0.057879  0.799479  0.720321
# 2018-01-07 -0.001609  2.261175  0.523525  1.551756 -0.180103
# 2018-01-08 -1.486153 -1.034948  0.551709  1.254316 -0.712418
# 2018-01-09  0.212726  0.141629  0.511056  1.233897 -1.262174
# 2018-01-10 -0.308270 -1.520049 -0.595410  0.113197 -0.085323

# %%
df[1:5]
# Out:
#                    A         B         C         D         E
# 2018-01-02  0.325065  0.273304 -0.542972  0.362559 -1.695097
# 2018-01-03  0.566284  0.955994 -1.219319  0.320732 -1.078282
# 2018-01-04 -1.078971  0.500797 -0.804943  1.752690  0.048946
# 2018-01-05  0.001632 -0.239746  0.824127 -1.293073 -1.384304

# %%
df.loc[:, ['B', 'C', 'D']]
# Out:
#                    B         C         D
# 2018-01-01 -1.139564 -1.192824 -0.062274
# 2018-01-02  0.273304 -0.542972  0.362559
# 2018-01-03  0.955994 -1.219319  0.320732
# 2018-01-04  0.500797 -0.804943  1.752690
# 2018-01-05 -0.239746  0.824127 -1.293073
# ...              ...       ...       ...
# 2019-08-19 -0.707023 -0.956958  0.948464
# 2019-08-20  0.350109 -0.353701 -1.068761
# 2019-08-21 -0.078161 -1.427209 -0.053864
# 2019-08-22 -1.250989  0.025064 -0.345507
# 2019-08-23 -0.293466 -0.013821 -0.343780
#
# [600 rows x 3 columns]

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2018-01-01 -2.684927 -1.139564 -1.192824 -0.062274  0.360303
# 2018-01-02  0.325065  0.273304 -0.542972  0.362559 -1.695097
# 2018-01-03  0.566284  0.955994 -1.219319  0.320732 -1.078282

# %%
f = df.loc['20180301':'20180917', ['A', 'E']]

# %%
len(f)
# Out:
# 201

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2018-01-01 -2.684927 -1.139564 -1.192824 -0.062274  0.360303
# 2018-01-02  0.325065  0.273304 -0.542972  0.362559 -1.695097
# 2018-01-03  0.566284  0.955994 -1.219319  0.320732 -1.078282

# %%
df.iloc[1:4, 1:3]
# Out:
#                    B         C
# 2018-01-02  0.273304 -0.542972
# 2018-01-03  0.955994 -1.219319
# 2018-01-04  0.500797 -0.804943

# %%
df.iloc[[1, 5, 6], [0, 3]]
# Out:
#                    A         D
# 2018-01-02  0.325065  0.362559
# 2018-01-06 -1.222225  0.799479
# 2018-01-07 -0.001609  1.551756

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D         E
# 2018-01-02  0.325065  0.273304 -0.542972  0.362559 -1.695097
# 2018-01-03  0.566284  0.955994 -1.219319  0.320732 -1.078282

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2018-01-01 -2.684927 -1.139564 -1.192824 -0.062274  0.360303
# 2018-01-02  0.325065  0.273304 -0.542972  0.362559 -1.695097
# 2018-01-03  0.566284  0.955994 -1.219319  0.320732 -1.078282

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D         E
# 2018-01-02  0.325065  0.273304 -0.542972  0.362559 -1.695097
# 2018-01-03  0.566284  0.955994 -1.219319  0.320732 -1.078282
# 2018-01-05  0.001632 -0.239746  0.824127 -1.293073 -1.384304
# 2018-01-09  0.212726  0.141629  0.511056  1.233897 -1.262174
# 2018-01-12  0.881285  0.297756  1.801978 -0.476010 -1.326665
# ...              ...       ...       ...       ...       ...
# 2019-08-12  0.792157  0.841186  0.074231 -0.282417 -0.599281
# 2019-08-13  0.022296  0.691292 -1.298401 -0.296430  0.608805
# 2019-08-14  1.031334  0.282995  0.425910 -0.720754 -0.200753
# 2019-08-18  1.650313  0.070717 -0.488307  0.318351 -0.138915
# 2019-08-22  0.598246 -1.250989  0.025064 -0.345507  2.710315
#
# [306 rows x 5 columns]

# %%
df[df > 0]
# Out:
#                    A         B         C         D         E
# 2018-01-01       NaN       NaN       NaN       NaN  0.360303
# 2018-01-02  0.325065  0.273304       NaN  0.362559       NaN
# 2018-01-03  0.566284  0.955994       NaN  0.320732       NaN
# 2018-01-04       NaN  0.500797       NaN  1.752690  0.048946
# 2018-01-05  0.001632       NaN  0.824127       NaN       NaN
# ...              ...       ...       ...       ...       ...
# 2019-08-19       NaN       NaN       NaN  0.948464  0.212380
# 2019-08-20       NaN  0.350109       NaN       NaN  0.666127
# 2019-08-21       NaN       NaN       NaN       NaN  0.787226
# 2019-08-22  0.598246       NaN  0.025064       NaN  2.710315
# 2019-08-23       NaN       NaN       NaN       NaN       NaN
#
# [600 rows x 5 columns]
