# %%
import pandas as pd
import numpy as np

# %%
header = pd.MultiIndex.from_product(
    [['Período 1', 'Período 2'], ['Matemática', 'Estatística']])

d = ([[12, 45, 67, 56], [78, 89, 45, 67], [45, 67, 89, 90], [67, 44, 56, 55]])

# %%
df = pd.DataFrame(d,
                  index=['Pedro', 'Felipe', 'Ricardo', 'Diego'],
                  columns=header)

# %%
header
# Out:
# MultiIndex([('Período 1',  'Matemática'),
#             ('Período 1', 'Estatística'),
#             ('Período 2',  'Matemática'),
#             ('Período 2', 'Estatística')],
#            )

# %%
df
# Out:
#          Período 1              Período 2
#         Matemática Estatística Matemática Estatística
# Pedro           12          45         67          56
# Felipe          78          89         45          67
# Ricardo         45          67         89          90
# Diego           67          44         56          55
