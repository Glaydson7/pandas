# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20200101', periods=6)

df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns=[
                  'Var_A', 'Var_B', 'Var_C', 'Var_D'])

# %%
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01  0.063421 -0.136992 -0.445542  0.456216
# 2020-01-02  0.267122 -0.550547 -2.358544 -2.436248
# 2020-01-03  1.366822  0.094774 -0.329445  0.543495
# 2020-01-04 -1.885060  0.232177  0.767461  0.341542
# 2020-01-05 -0.034864  2.887750  1.772333  0.562019
# 2020-01-06  0.314099  1.839231 -0.305721  1.808692

# %%
dft = df.T

# %%
dft
# Out:
#        2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05  2020-01-06
# Var_A    0.063421    0.267122    1.366822   -1.885060   -0.034864    0.314099
# Var_B   -0.136992   -0.550547    0.094774    0.232177    2.887750    1.839231
# Var_C   -0.445542   -2.358544   -0.329445    0.767461    1.772333   -0.305721
# Var_D    0.456216   -2.436248    0.543495    0.341542    0.562019    1.808692

# %%
df.shape
# Out:
# (6, 4)

# %%
dft.shape
# Out:
# (4, 6)

# %%
np.size(dft.values)
# Out:
# 24

# %%
dft.values
# Out:
# array([[ 0.06342134,  0.26712239,  1.36682157, -1.88505966, -0.03486355,
#          0.31409857],
#        [-0.13699198, -0.55054722,  0.09477394,  0.23217737,  2.88774979,
#          1.83923098],
#        [-0.44554198, -2.35854381, -0.32944454,  0.7674613 ,  1.77233348,
#         -0.30572119],
#        [ 0.45621622, -2.43624789,  0.5434949 ,  0.34154186,  0.56201918,
#          1.80869249]])

# %%
v = dft.values

# %%
v.reshape((3, 12))
# Out:
# array([[ 0.06342134,  0.26712239,  1.36682157, -1.88505966, -0.03486355,
#          0.31409857, -0.13699198, -0.55054722,  0.09477394,  0.23217737,
#          2.88774979,  1.83923098],
#        [-0.44554198, -2.35854381, -0.32944454,  0.7674613 ,  1.77233348,
#         -0.30572119,  0.45621622, -2.43624789,  0.5434949 ,  0.34154186,
#          0.56201918,  1.80869249]])
