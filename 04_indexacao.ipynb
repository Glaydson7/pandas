# %%
import numpy as np

# %%
v = [22, 55, 7, 9]

# %%
v
# Out:
# [22, 55, 7, 9]

# %%
v[2]
# Out:
# 7

# %%
v[0]
# Out:
# 22

# %%
v[-1]
# Out:
# 9

# %%
v
# Out:
# [22, 55, 7, 9]

# %%
v[-5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 v[-5]
#
# IndexError: list index out of range
