# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20200101', periods=6)

df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns=[
                  'Var_A', 'Var_B', 'Var_C', 'Var_D'])

# %%
df2 = pd.DataFrame({'A': 1.,
   ...:                     'B': pd.Timestamp('20130102'),
   ...:                     'C': pd.Series(1, index=list(range(4)), dtype='float32'),
   ...:                     'D': np.array([3] * 4, dtype='int32'),
   ...:                     'E': pd.Categorical(["test", "train", "test", "train"]),
   ...:                     'F': 'Python'})

# %%
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01 -0.330181  1.256124 -2.171025 -0.721964
# 2020-01-02 -0.772601  1.289067  1.003687 -0.795560
# 2020-01-03  0.080832 -0.542673 -0.279155 -1.485977
# 2020-01-04 -0.422384  0.366477  0.538522  0.380321
# 2020-01-05 -0.990053 -1.390954 -0.181009  0.515187
# 2020-01-06  0.985162 -0.124501  1.249371 -1.297116

# %%
df.shape
# Out:
# (6, 4)

# %%
df.dtypes
# Out:
# Var_A    float64
# Var_B    float64
# Var_C    float64
# Var_D    float64
# dtype: object

# %%
df2
# Out:
#      A          B    C  D      E       F
# 0  1.0 2013-01-02  1.0  3   test  Python
# 1  1.0 2013-01-02  1.0  3  train  Python
# 2  1.0 2013-01-02  1.0  3   test  Python
# 3  1.0 2013-01-02  1.0  3  train  Python

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01 -0.330181  1.256124 -2.171025 -0.721964
# 2020-01-02 -0.772601  1.289067  1.003687 -0.795560
# 2020-01-03  0.080832 -0.542673 -0.279155 -1.485977
# 2020-01-04 -0.422384  0.366477  0.538522  0.380321
# 2020-01-05 -0.990053 -1.390954 -0.181009  0.515187
# 2020-01-06  0.985162 -0.124501  1.249371 -1.297116

# %%
df1 = df.reindex(index=datas[0:4], columns=list(df.columns) + ['Var_E'])

# %%
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01 -0.330181  1.256124 -2.171025 -0.721964    NaN
# 2020-01-02 -0.772601  1.289067  1.003687 -0.795560    NaN
# 2020-01-03  0.080832 -0.542673 -0.279155 -1.485977    NaN
# 2020-01-04 -0.422384  0.366477  0.538522  0.380321    NaN

# %%
df1.loc[datas[0]:datas[1], 'Var_E'] = 77

# %%
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01 -0.330181  1.256124 -2.171025 -0.721964   77.0
# 2020-01-02 -0.772601  1.289067  1.003687 -0.795560   77.0
# 2020-01-03  0.080832 -0.542673 -0.279155 -1.485977    NaN
# 2020-01-04 -0.422384  0.366477  0.538522  0.380321    NaN

# %%
df1.dtypes
# Out:
# Var_A    float64
# Var_B    float64
# Var_C    float64
# Var_D    float64
# Var_E    float64
# dtype: object

# %%
df1.describe()
# Out:
#           Var_A     Var_B     Var_C     Var_D  Var_E
# count  4.000000  4.000000  4.000000  4.000000    2.0
# mean  -0.361084  0.592249 -0.226993 -0.655795   77.0
# std    0.350879  0.868966  1.400306  0.771719    0.0
# min   -0.772601 -0.542673 -2.171025 -1.485977   77.0
# 25%   -0.509939  0.139189 -0.752122 -0.968164   77.0
# 50%   -0.376283  0.811300  0.129684 -0.758762   77.0
# 75%   -0.227428  1.264360  0.654813 -0.446393   77.0
# max    0.080832  1.289067  1.003687  0.380321   77.0

# %% [markdown]
# # dados missing

# %%
df1.isna().sum()
# Out:
# Var_A    0
# Var_B    0
# Var_C    0
# Var_D    0
# Var_E    2
# dtype: int64

# %%
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01 -0.330181  1.256124 -2.171025 -0.721964   77.0
# 2020-01-02 -0.772601  1.289067  1.003687 -0.795560   77.0
# 2020-01-03  0.080832 -0.542673 -0.279155 -1.485977    NaN
# 2020-01-04 -0.422384  0.366477  0.538522  0.380321    NaN

# %%
df1.dropna(axis=0, how='any')
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01 -0.330181  1.256124 -2.171025 -0.721964   77.0
# 2020-01-02 -0.772601  1.289067  1.003687 -0.795560   77.0

# %%
df1.dropna(axis=1, how='any')
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01 -0.330181  1.256124 -2.171025 -0.721964
# 2020-01-02 -0.772601  1.289067  1.003687 -0.795560
# 2020-01-03  0.080832 -0.542673 -0.279155 -1.485977
# 2020-01-04 -0.422384  0.366477  0.538522  0.380321
