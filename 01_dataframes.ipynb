# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([7, 4, 2, np.nan, 6, 9])

# %%
series
# Out:
# 0    7.0
# 1    4.0
# 2    2.0
# 3    NaN
# 4    6.0
# 5    9.0
# dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
datas = pd.date_range('20180101', periods=6, freq="D")

# %%
datas
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
type(datas)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=datas,
                  columns=list("ABCD"))  # list("ABCD")

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01 -2.047185 -2.019110 -0.266251  0.101645
# 2018-01-02 -0.052576 -0.904130  0.496369  0.071525
# 2018-01-03 -0.747210 -1.108568 -0.717025  0.210031
# 2018-01-04 -0.874698  0.749655 -0.501796 -1.316622
# 2018-01-05 -0.118821  0.483256 -0.704623  1.417600
# 2018-01-06 -1.370994  0.392675 -0.246307 -1.324726

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.DataFrame({"A": 7,
                   'B': pd.Timestamp('20190101'),
                    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
                    "D": np.array([3] * 4, dtype='int32'),
                    "E": pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'Python'})

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3   test  Python
# 1  7 2019-01-01  1.0  3  train  Python
# 2  7 2019-01-01  1.0  3   test  Python
# 3  7 2019-01-01  1.0  3  train  Python

# %%
df2.dtypes
# Out:
# A            int64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01 -2.047185 -2.019110 -0.266251  0.101645
# 2018-01-02 -0.052576 -0.904130  0.496369  0.071525
# 2018-01-03 -0.747210 -1.108568 -0.717025  0.210031
# 2018-01-04 -0.874698  0.749655 -0.501796 -1.316622
# 2018-01-05 -0.118821  0.483256 -0.704623  1.417600
# 2018-01-06 -1.370994  0.392675 -0.246307 -1.324726

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3   test  Python
# 1  7 2019-01-01  1.0  3  train  Python
# 2  7 2019-01-01  1.0  3   test  Python
# 3  7 2019-01-01  1.0  3  train  Python

# %% [markdown]
# # Visualizar dados

# %%
df.head(2)
# Out:
#                    A        B         C         D
# 2018-01-01 -2.047185 -2.01911 -0.266251  0.101645
# 2018-01-02 -0.052576 -0.90413  0.496369  0.071525

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2018-01-04 -0.874698  0.749655 -0.501796 -1.316622
# 2018-01-05 -0.118821  0.483256 -0.704623  1.417600
# 2018-01-06 -1.370994  0.392675 -0.246307 -1.324726

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
c = df.columns

# %%
c
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01 -2.047185 -2.019110 -0.266251  0.101645
# 2018-01-02 -0.052576 -0.904130  0.496369  0.071525
# 2018-01-03 -0.747210 -1.108568 -0.717025  0.210031
# 2018-01-04 -0.874698  0.749655 -0.501796 -1.316622
# 2018-01-05 -0.118821  0.483256 -0.704623  1.417600
# 2018-01-06 -1.370994  0.392675 -0.246307 -1.324726

# %%
df.to_numpy()
# Out:
# array([[-2.04718475, -2.01911039, -0.26625126,  0.10164469],
#        [-0.05257596, -0.90412951,  0.49636893,  0.07152485],
#        [-0.74721034, -1.10856824, -0.7170247 ,  0.21003064],
#        [-0.87469808,  0.74965548, -0.50179647, -1.31662202],
#        [-0.11882059,  0.48325591, -0.7046231 ,  1.41759957],
#        [-1.37099386,  0.39267472, -0.24630672, -1.32472636]])

# %%
df.T
# Out:
#    2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05  2018-01-06
# A   -2.047185   -0.052576   -0.747210   -0.874698   -0.118821   -1.370994
# B   -2.019110   -0.904130   -1.108568    0.749655    0.483256    0.392675
# C   -0.266251    0.496369   -0.717025   -0.501796   -0.704623   -0.246307
# D    0.101645    0.071525    0.210031   -1.316622    1.417600   -1.324726

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                    7                    7                    7
# B  2019-01-01 00:00:00  2019-01-01 00:00:00  2019-01-01 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F               Python               Python               Python
#
#                      3
# A                    7
# B  2019-01-01 00:00:00
# C                  1.0
# D                    3
# E                train
# F               Python

# %%
df2.to_numpy()
# Out:
# array([[7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'Python']],
#       dtype=object)
